# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pathlib
if pathlib.Path().resolve().name == 'notebooks':
    # %cd ..
# %pwd
# Out:
# '/home/shabgard/ift6758-venv/project/NHL'

# %%
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
from src.data import load_data, load_processed_data, load_df_shots

# %%
df = load_df_shots(2018)
df
# Out:
# Processing data... (1-2 minutes)
# Downloading:
#  Regulars: 1271/1271
#  Playoffs: 105/105
# Season 2018 successfully saved to file
# Done!
# Creating Dataframe...
# Done!
#        Game Id  Periode Temps écoulé Equipe   Goal     X     Y  \
# 0            1        1        00:29    MTL  False  78.0 -19.0
# 1            1        1        00:49    TOR  False -37.0 -10.0
# 2            1        1        01:00    MTL  False  47.0 -23.0
# 3            1        1        03:54    MTL  False  53.0  14.0
# 4            1        1        04:06    MTL  False  77.0  -2.0
# ...        ...      ...          ...    ...    ...   ...   ...
# 77809     1271        3        15:37    SJS  False  67.0 -19.0
# 77810     1271        3        16:33    COL  False -78.0   1.0
# 77811     1271        3        18:39    COL  False -82.0  10.0
# 77812     1271        3        18:40    COL  False -81.0   1.0
# 77813     1271        3        19:15    SJS   True  74.0   4.0
#
#                   Tireur            Gardien        Type Filet Vide Force  \
# 0       Artturi Lehkonen  Frederik Andersen    Backhand       None
# 1          Morgan Rielly        Carey Price   Snap Shot       None
# 2      Brendan Gallagher  Frederik Andersen  Wrist Shot       None
# 3      Brendan Gallagher  Frederik Andersen   Snap Shot       None
# 4            Mike Reilly  Frederik Andersen   Snap Shot       None
# ...                  ...                ...         ...        ...   ...
# 77809       Joe Pavelski    Semyon Varlamov   Slap Shot       None
# 77810  Gabriel Landeskog       Martin Jones  Wrist Shot       None
# 77811  Gabriel Landeskog       Martin Jones  Wrist Shot       None
# 77812     Carl Soderberg       Martin Jones  Wrist Shot       None
# 77813      Micheal Haley                     Wrist Shot       True  Even
#
#        Net distance
# 0         21.954498
# 1         52.952809
# 2         47.885280
# 3         38.626416
# 4         12.165525
# ...             ...
# 77809     29.068884
# 77810     11.045361
# 77811     12.206556
# 77812      8.062258
# 77813     15.524175
#
# [77814 rows x 13 columns]
